# %%
import pandas as pd
df = pd.read_csv('../data/generated_training.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   languageCode  1300 non-null   object
#  1   prompt        1300 non-null   object
#  2   schema        1300 non-null   object
#  3   response      1300 non-null   object
# dtypes: object(4)
# memory usage: 40.8+ KB

# %%
# Create another column json_response with the content of response but removing ```json and ``` to only include the code
df['json_response'] = df['response'].str.replace('```json\n', '').str.replace('```', '')

# %%
import jsonschema
import json

def validate_response(row):
    if row['json_response']==None:
        return {"validate": False,
                "error_code": 3,
                "error_message":"Empty JSON"}
        
    try:
    # If no exception is raised by validate(), the instance is valid.
        schema=json.loads(row['schema'])
        response=json.loads(row['json_response'])
        jsonschema.validate(response, schema=schema)

        return {"validate": True,
                "error_code": 0,
                "error_message":"Valid JSON"}
    except jsonschema.exceptions.SchemaError as e:
        return {"validate": False,
                "error_code": 1, #schema
                "error_message": f"{e.message}"}
    except jsonschema.exceptions.ValidationError as e: 
        error_message=validate_response_all_errors(row)
        output={"validate": False,
        "error_code": 2,
        "error_message": error_message}
        return output
    except Exception as e:
        return {"validate": False,
                "error_code": 3,
                "error_message":f"Exception {e}"}

def validate_response_all_errors(row):
        schema=json.loads(row['schema'])
        response=json.loads(row['json_response'])
        errors=jsonschema.Draft202012Validator(schema).iter_errors(response)
        error_message=[]
        for e in errors:
            error_message.append({
"message": f'{e.message}',
"validator": f'{e.validator}',
"validator_type": f'{e.validator_value}',
"json_path": e.json_path,
#"json_path": e.relative_path,
#"context": e.context,
#"cause": e.cause
})
        return error_message

# %%
# Create new column with the error message of validation of the json_response and the schema using the function validate_response
df['validation_result'] = df.apply(lambda row: validate_response(row), axis=1)
df['error_message'] = df['validation_result'].apply(lambda x: x['error_message'])
df['valid'] = df['validation_result'].apply(lambda x: x['validate'])
df['error_code'] = df['validation_result'].apply(lambda x: x['error_code'])
df['error_message_len'] = df['error_message'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %%
df['valid'].value_counts()
# Out:
# valid
# False    928
# True     372
# Name: count, dtype: int64

# %%
# Create a column with the len of json in column error_message if the content is a json array

# %%
df['error_message_len'].value_counts()
# Out:
# error_message_len
# 0     428
# 1     359
# 2     173
# 3      91
# 4      44
# 5      43
# 6      33
# 8      19
# 10     17
# 7      15
# 9      14
# 12     11
# 13      5
# 11      5
# 16      4
# 18      4
# 33      3
# 20      3
# 17      3
# 15      3
# 14      3
# 30      2
# 37      2
# 23      1
# 27      1
# 25      1
# 57      1
# 31      1
# 24      1
# 42      1
# 21      1
# 46      1
# 68      1
# 43      1
# 28      1
# 32      1
# 71      1
# 36      1
# 26      1
# Name: count, dtype: int64

# %%
filter_one_error=df[df['error_message_len']==2]
#print(filter_one_error['error_message'].head(20).to_markdown())
print(filter_one_error['validation_result'].head(20).to_markdown())
# Out:
# |     | validation_result                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |----:|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |  22 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.header.in_reply_to'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.options.scheduled_send_time'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |  36 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "{'type': 'Custom', 'cron_expression': '0 0 * * MON#2,MON#4'} is not valid under any of the given schemas", 'validator': 'anyOf', 'validator_type': "[{'properties': {'type': {'type': 'string', 'enum': ['Daily']}}, 'required': ['type']}, {'properties': {'type': {'type': 'string', 'enum': ['Weekly']}, 'day_of_week': {'type': 'integer', 'minimum': 1, 'maximum': 7}}, 'required': ['type', 'day_of_week']}, {'properties': {'type': {'type': 'string', 'enum': ['Monthly']}, 'day_of_month': {'type': 'integer', 'minimum': 1, 'maximum': 31}}, 'required': ['type', 'day_of_month']}, {'properties': {'type': {'type': 'string', 'enum': ['Quarterly']}, 'start_month': {'type': 'integer', 'enum': [1, 4, 7, 10]}}, 'required': ['type', 'start_month']}, {'properties': {'type': {'type': 'string', 'enum': ['Yearly']}, 'month_of_year': {'type': 'integer', 'minimum': 1, 'maximum': 12}, 'day_of_month': {'type': 'integer', 'minimum': 1, 'maximum': 31}}, 'required': ['type', 'month_of_year', 'day_of_month']}, {'properties': {'type': {'type': 'string', 'enum': ['Custom']}, 'cron_expression': {'type': 'string', 'pattern': '^([^ ]+ ){5,6}([^ ]+)?$'}}, 'required': ['type', 'cron_expression']}, {'properties': {'type': {'type': 'string', 'enum': ['OnDemand']}}, 'required': ['type']}]", 'json_path': '$.maintenance_tasks[0].frequency'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.schedule_details.recurrence_rule'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |  46 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'number'", 'validator': 'type', 'validator_type': 'number', 'json_path': '$[1].environmentalImpactAssessment.noiseLevel_dBA'}, {'message': "None is not of type 'number'", 'validator': 'type', 'validator_type': 'number', 'json_path': '$[2].environmentalImpactAssessment.noiseLevel_dBA'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |  47 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.evaluationResults[1].suggestedModifications'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.evaluationResults[2].suggestedModifications'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |  51 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.modules[0].content[0].textContent'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.modules[2].content[0].textContent'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |  79 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.references[0].doi'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.references[1].doi'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# |  81 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.connectors[0].conditionExpression'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.connectors[0].conditionDataPath'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |  82 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "{'listType': 'unordered', 'listItems': ['Create an emergency fund.', 'Live below your means.', 'Regularly review your budget.', 'Avoid unnecessary spending.', 'Save automatically each month.']} is not valid under any of the given schemas", 'validator': 'anyOf', 'validator_type': "[{'type': 'string'}, {'type': 'object', 'properties': {'subsectionTitle': {'type': 'string'}, 'subsectionContent': {'type': 'array', 'items': {'anyOf': [{'type': 'string'}, {'type': 'object', 'properties': {'exampleType': {'type': 'string', 'enum': ['calculation', 'tip', 'warning', 'recommendation', 'definition']}, 'exampleTitle': {'type': 'string'}, 'exampleDescription': {'type': 'string'}, 'calculationSteps': {'type': 'array', 'items': {'type': 'object', 'properties': {'stepNumber': {'type': 'integer', 'minimum': 1}, 'stepDescription': {'type': 'string'}, 'formula': {'type': 'string'}, 'inputVariables': {'type': 'array', 'items': {'type': 'string'}}, 'outputVariable': {'type': 'string'}}, 'required': ['stepNumber', 'stepDescription']}}, 'dataSchema': {'type': 'object'}, 'sampleData': {'type': 'object'}}, 'required': ['exampleType', 'exampleDescription']}, {'type': 'object', 'properties': {'listType': {'type': 'string', 'enum': ['unordered', 'ordered']}, 'listItems': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}}, 'required': ['listType', 'listItems']}, {'type': 'object', 'properties': {'tableTitle': {'type': 'string'}, 'headers': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}, 'rows': {'type': 'array', 'items': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}, 'minItems': 1}}, 'required': ['headers', 'rows']}]}}}, 'required': ['subsectionTitle', 'subsectionContent']}]", 'json_path': '$.sections[4].sectionContent[1]'}, {'message': "{'tableTitle': 'Key Credit Score Factors', 'headers': ['Factor', 'Percentage Importance'], 'rows': [['Payment History', '35%'], ['Amounts Owed', '30%'], ['Length of Credit History', '15%'], ['New Credit', '10%'], ['Credit Mix', '10%']]} is not valid under any of the given schemas", 'validator': 'anyOf', 'validator_type': "[{'type': 'string'}, {'type': 'object', 'properties': {'subsectionTitle': {'type': 'string'}, 'subsectionContent': {'type': 'array', 'items': {'anyOf': [{'type': 'string'}, {'type': 'object', 'properties': {'exampleType': {'type': 'string', 'enum': ['calculation', 'tip', 'warning', 'recommendation', 'definition']}, 'exampleTitle': {'type': 'string'}, 'exampleDescription': {'type': 'string'}, 'calculationSteps': {'type': 'array', 'items': {'type': 'object', 'properties': {'stepNumber': {'type': 'integer', 'minimum': 1}, 'stepDescription': {'type': 'string'}, 'formula': {'type': 'string'}, 'inputVariables': {'type': 'array', 'items': {'type': 'string'}}, 'outputVariable': {'type': 'string'}}, 'required': ['stepNumber', 'stepDescription']}}, 'dataSchema': {'type': 'object'}, 'sampleData': {'type': 'object'}}, 'required': ['exampleType', 'exampleDescription']}, {'type': 'object', 'properties': {'listType': {'type': 'string', 'enum': ['unordered', 'ordered']}, 'listItems': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}}, 'required': ['listType', 'listItems']}, {'type': 'object', 'properties': {'tableTitle': {'type': 'string'}, 'headers': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}, 'rows': {'type': 'array', 'items': {'type': 'array', 'items': {'type': 'string'}, 'minItems': 1}, 'minItems': 1}}, 'required': ['headers', 'rows']}]}}}, 'required': ['subsectionTitle', 'subsectionContent']}]", 'json_path': '$.sections[5].sectionContent[1]'}]} |
# |  83 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.content_metadata.ad_id'}, {'message': "Additional properties are not allowed ('engagement_metrics_july_2_reel' was unexpected)", 'validator': 'additionalProperties', 'validator_type': 'False', 'json_path': '$'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |  85 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "'interplanetary' is not one of ['stone age', 'bronze age', 'iron age', 'industrial age', 'information age', 'space age', 'interstellar age', 'galactic age', 'universal age', 'transcendent']", 'validator': 'enum', 'validator_type': "['stone age', 'bronze age', 'iron age', 'industrial age', 'information age', 'space age', 'interstellar age', 'galactic age', 'universal age', 'transcendent']", 'json_path': '$.technologicalAdvancement.technologyLevel'}, {'message': "'high pressure' is not one of ['high gravity', 'low gravity', 'dense atmosphere', 'thin atmosphere', 'toxic atmosphere', 'oxygen-rich atmosphere', 'methane atmosphere', 'extreme temperatures', 'temperate climate', 'high radiation', 'low radiation', 'tidally locked', 'rapid rotation', 'slow rotation', 'high axial tilt', 'low axial tilt', 'abundant water', 'scarce water', 'strong magnetic field', 'weak magnetic field']", 'validator': 'enum', 'validator_type': "['high gravity', 'low gravity', 'dense atmosphere', 'thin atmosphere', 'toxic atmosphere', 'oxygen-rich atmosphere', 'methane atmosphere', 'extreme temperatures', 'temperate climate', 'high radiation', 'low radiation', 'tidally locked', 'rapid rotation', 'slow rotation', 'high axial tilt', 'low axial tilt', 'abundant water', 'scarce water', 'strong magnetic field', 'weak magnetic field']", 'json_path': '$.homeworldInformation.environmentalConditions[3]'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |  92 | {'validate': False, 'error_code': 2, 'error_message': [{'message': '[] should be non-empty', 'validator': 'minItems', 'validator_type': '1', 'json_path': '$.sections[1].questions[2].response_options'}, {'message': '[] should be non-empty', 'validator': 'minItems', 'validator_type': '1', 'json_path': '$.sections[1].questions[3].response_options'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# ...
# | 137 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "'month' is not one of ['days', 'weeks', 'months', 'years']", 'validator': 'enum', 'validator_type': "['days', 'weeks', 'months', 'years']", 'json_path': '$.teacher_development.development_initiatives[1].program_duration.duration_unit'}, {'message': "'Enrichment programs' is not one of ['Counseling services', 'Tutoring programs', 'Special education services', 'Financial aid', 'Mentoring programs', 'Health services', 'Nutritional support', 'Transportation assistance', 'Extracurricular activities']", 'validator': 'enum', 'validator_type': "['Counseling services', 'Tutoring programs', 'Special education services', 'Financial aid', 'Mentoring programs', 'Health services', 'Nutritional support', 'Transportation assistance', 'Extracurricular activities']", 'json_path': '$.student_support_services.support_programs[1].services_provided[0]'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | 142 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.plant_species.plant_characteristics.size.height.range'}, {'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.plant_species.plant_characteristics.fruit.size.range'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | 146 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'string'", 'validator': 'type', 'validator_type': 'string', 'json_path': '$.feedback.organizer_feedback'}, {'message': "None is not of type 'number'", 'validator': 'type', 'validator_type': 'number', 'json_path': '$.feedback.overall_rating'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | 147 | {'validate': False, 'error_code': 2, 'error_message': [{'message': "None is not of type 'object'", 'validator': 'type', 'validator_type': 'object', 'json_path': '$.earningRules[0].frequencyLimit'}, {'message': "None is not of type 'object'", 'validator': 'type', 'validator_type': 'object', 'json_path': '$.partnerships[1].contactInformation'}]}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
